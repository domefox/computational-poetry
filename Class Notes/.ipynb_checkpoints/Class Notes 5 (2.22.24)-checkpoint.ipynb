# %%
5 + 5
# Out:
# 10

# %% [markdown]
# hello my name is weber wong and this markdown which is just text
# # this is a header, using a pound sign
# this is *italicized* which is using asteriks
# https://www.markdownguide.org/basic-syntax/

# %% [markdown]
# a - make cell above
#
# b - make cell below
#
# d - delete
#
# m - markdown
#
# y - code
#
# ctrl + enter - run cell
#
# shift + enter - run cell & go to next one

# %% [markdown]
# # some python
#
# expression -> interpreter (evaluates) -> value
#
# statements ->

# %%
4 + 6
# Out:
# 10

# %%
8 == 4 *2
# is equals
# Out:
# True

# %% [markdown]
# # values have types

# %%
type(15.6)
# type is to figure out what you're tryna do with it
# Out:
# float

# %%
type(15)
# Out:
# int

# %%
type(True)
# Out:
# bool

# %% [markdown]
# # variables in python

# %%
mortimer = 4 + 5 * 6 # this is just setting a value

# %%
mortimer + 2
# Out:
# 36

# %%
glorp + 8
# Out:
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 glorp + 8
#
# NameError: name 'glorp' is not defined

# %%
type (mortimer)
# Out:
# int

# %%
type (mortimer/2)
# Out:
# float

# %%
5 % 2
# Out:
# 1

# %% [markdown]
# # strings!

# %%
"hello my name is weber and this is a string literal as they say"
# Out:
# 'hello my name is weber and this is a string literal as they say'

# %%
greeting = "hello my name is weber and this is a string literal as they say"

# %%
greeting
# Out:
# 'hello my name is weber and this is a string literal as they say'

# %%
type(greeting)
# Out:
# str

# %%
len(greeting)
# Out:
# 63

# %%
x = "name"
x in greeting
# Out:
# True

# %%
z = 'hello'

# %% [markdown]
# # quoting and escape characters
# And then he said "I think that's a cool idea" and vanished
# can use single quote inside double quote and vice versa
# "\" in front of apostrophe

# %%
z = 'And then he said, "I think that\'s a cool idea," and vanished'

# %%
z
# Out:
# 'And then he said, "I think that\'s a cool idea," and vanished'

# %%
print(z)
# Out:
# And then he said, "I think that's a cool idea," and vanished

# %% [markdown]
# print makes it look like it should without the backslash

# %%
# \" - \ is a break character to let things show up despite the syntax of pythob
a = "And then she said, \"Hey.\""

# %%
print(a)
# Out:
# And then she said, "Hey."

# %%
# \n - line break
b = "One two three\nfour five six"

# %%
b
# Out:
# 'One two three\nfour five six'

# %%
print(b)
# Out:
# One two three
# four five six

# %% [markdown]
# # string methods

# %%
greeting
# Out:
# 'hello my name is weber and this is a string literal as they say'

# %%
greeting.startswith("hell")
# Out:
# True

# %%
greeting.startswith("bleah")
# Out:
# False

# %%
greeting.find("name") # which character it starts at
# Out:
# 9

# %%
# index, many other methods using string methods

# %%
6 == 5
# Out:
# False

# %%
greeting == "aasdasda"
# Out:
# False

# %%
"blarg" == "blarg"
# Out:
# True

# %%
"b" > "a"
# Out:
# True

# %% [markdown]
# # string transformations!

# %%
greeting.upper()
# Out:
# 'HELLO MY NAME IS WEBER AND THIS IS A STRING LITERAL AS THEY SAY'

# %%
"ARGUMENTATION! YELLING!".lower()
# Out:
# 'argumentation! yelling!'

# %%
greeting.lower()
# Out:
# 'hello my name is weber and this is a string literal as they say'

# %%
# typically doesn't change underlying object / string, returns a copy of it with the transformations

# %%
data = "     hello there this is a test!      \n"

# %%
data.strip()
# Out:
# 'hello there this is a test!'

# %%
greeting.replace("hello","goodbye")
# Out:
# 'goodbye my name is weber and this is a string literal as they say'

# %%
skydiving = greeting.replace("a", "aaaAAAAaaa")

# %%
skydiving
# Out:
# 'hello my naaaAAAAaaame is weber aaaAAAAaaand this is aaaAAAAaaa string literaaaAAAAaaal aaaAAAAaaas they saaaAAAAaaay'

# %% [markdown]
# # reading

# %%
text = open("sea_rose.txt").read() # prob needs to be there
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 text = open("sea_rose.txt").read()
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sea_rose.txt'

# %%
print(text.replace(","))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 print(text.replace(","))
#
# TypeError: replace expected at least 2 arguments, got 1

# %%
text = "a colorful cubist chained in plato's cave, I found that ignorance is iridescent bliss"

# %%
print(text.replace("I", "🌼"))
# Out:
# a colorful cubist chained in plato's cave, 🌼 found that ignorance is iridescent bliss

# %%
"cubist" in text
# Out:
# True

# %% [markdown]
# # list!

# %% [markdown]
# python list -> javascript array
#
# file -> string -> list -> filtering / transformation -> string -> screen/file
#
# this is the main workflow for editing poetry

# %%
[5, 10,15,20,25]
# Out:
# [5, 10, 15, 20, 25]

# %%
my_numbers = [5,10,15,20,25]

# %%
len([5])
# Out:
# 1

# %%
len([])
# Out:
# 0

# %%
my_numbers
# Out:
# [5, 10, 15, 20, 25]

# %%
my_numbers[3]
# Out:
# 20

# %%
my_numbers[len(my_numbers)-1]
# Out:
# 25

# %%
len(my_numbers) -2
# Out:
# 3

# %% [markdown]
# # negative indices and slices

# %%
my_numbers
# Out:
# [5, 10, 15, 20, 25]

# %%
my_numbers[-3]
# Out:
# 15

# %%
my_numbers[1:3]
# Out:
# [10, 15]

# %%
type(my_numbers[0])
# Out:
# int

# %%
type(my_numbers[1:3])
# Out:
# list

# %%
my_numbers[:3]
# Out:
# [5, 10, 15]

# %%
my_numbers[::-1]
# Out:
# [25, 20, 15, 10, 5]

# %%
my_numbers[4:-4]
# Out:
# []

# %%
greeting[-1]
# Out:
# 'y'

# %%
greeting[-2]
# Out:
# 'a'

# %%
greeting[5:15]
# Out:
# ' my name i'

# %% [markdown]
# # split and join
#
# * split: string --> list
# * join: list-> string

# %%
greeting
# Out:
# 'hello my name is weber and this is a string literal as they say'

# %%
greeting.split()
# Out:
# ['hello',
#  'my',
#  'name',
#  'is',
#  'weber',
#  'and',
#  'this',
#  'is',
#  'a',
#  'string',
#  'literal',
#  'as',
#  'they',
#  'say']

# %%
poem = text.split("\n")

# %%
poem[:3] + poem[-3:] # up to index 3, -3 from end to end
# Out:
# ["a colorful cubist chained in plato's cave, I found that ignorance is iridescent bliss",
#  "a colorful cubist chained in plato's cave, I found that ignorance is iridescent bliss"]

# %%
words = greeting.split()

# %%
words
# Out:
# ['hello',
#  'my',
#  'name',
#  'is',
#  'weber',
#  'and',
#  'this',
#  'is',
#  'a',
#  'string',
#  'literal',
#  'as',
#  'they',
#  'say']

# %%
" ".join(words) # this is the glue
# Out:
# 'hello my name is weber and this is a string literal as they say'

# %% [markdown]
# # randomness

# %%
import random

# %%
random.choice(words) # choice gives one
# Out:
# 'is'

# %%
print("\n".join(random.sample(words,3))) # sample gives however much you put for second one
# Out:
# weber
# is
# name

# %% [markdown]
# # list comprehensions
# [expression for type in list if condition]

# %%
[item for item in words]
# Out:
# ['hello',
#  'my',
#  'name',
#  'is',
#  'weber',
#  'and',
#  'this',
#  'is',
#  'a',
#  'string',
#  'literal',
#  'as',
#  'they',
#  'say']

# %%
[item.upper() for item in words]
# Out:
# ['HELLO',
#  'MY',
#  'NAME',
#  'IS',
#  'WEBER',
#  'AND',
#  'THIS',
#  'IS',
#  'A',
#  'STRING',
#  'LITERAL',
#  'AS',
#  'THEY',
#  'SAY']

# %%
[item[:3] for item in words]
# Out:
# ['hel',
#  'my',
#  'nam',
#  'is',
#  'web',
#  'and',
#  'thi',
#  'is',
#  'a',
#  'str',
#  'lit',
#  'as',
#  'the',
#  'say']

# %%
[item[:3] for item in words if len(item) > 3]
# Out:
# ['hel', 'nam', 'web', 'thi', 'str', 'lit', 'the']

# %%
"a" + "b"
# Out:
# 'ab'

# %% [markdown]
# # CLASS 4 2/15/24
#
# List comprehension & for loops

# %% [markdown]
# * input (texT) -> lines (units) -> list -> process -> output (lines)
# * input (list) -> processing -> output (list)
# * processing: transforming each item in the list; filtering (only include a subset of the lines in the output)

# %%
numbers = [5,10,15,20,25]
numbers
# Out:
# [5, 10, 15, 20, 25]

# %% [markdown]
# [*transform_expr* for item in list_to_process if filter_expr]

# %%
[x for x in numbers]
# Out:
# [5, 10, 15, 20, 25]

# %%
[x * 2 for x in numbers]
# Out:
# [10, 20, 30, 40, 50]

# %%
[item * item for item in numbers]
# Out:
# [25, 100, 225, 400, 625]

# %%
import random

# %%
random.random()
# Out:
# 0.9418092224119871

# %%
[item for item in numbers if random.random() > 0.5]
# Out:
# [10, 25]

# %%
[item * 5 for item in numbers if item >10]
# Out:
# [75, 100, 125]

# %%
text = open("idioms-Copy1.txt").read()

# %%
words = text.split()

# %%
["hello " + item.upper() for item in words if item.startswith('t')]
# Out:
# ['hello THE',
#  'hello THE',
#  'hello THE',
#  'hello THE',
#  'hello THE',
#  'hello THE',
#  'hello THE',
#  'hello THE',
#  'hello THAN',
#  'hello TWO',
#  'hello THE',
#  'hello THAN',
#  'hello THE',
#  'hello THE',
#  'hello THE',
#  'hello THE',
#  'hello THERE',
#  'hello THE',
#  'hello THE',
#  'hello THE',
#  'hello THE',
#  'hello THE',
#  'hello THE',
#  'hello THE',
#  'hello THE',
#  'hello TIME',
#  'hello THE',
#  'hello THAT',
#  'hello THE',
#  'hello THE',
#  'hello TO',
#  'hello THE',
#  'hello THEY',
#  'hello THE',
#  'hello TASTE',
#  'hello THAT',
#  'hello TO',
#  'hello TO',
#  'hello THE',
#  'hello TO',
#  'hello THE',
#  'hello THE',
#  'hello TH',
#  'hello TIP',
#  'hello THE',
#  'hello THE']

# %% [markdown]
# sometimes [x].[y] means calling method y from thing x.
# sometimes [x].[y] means calling method y from module x.

# %% [markdown]
# https://docs.python.org/3.5/library/ - all the standard things available

# %% [markdown]
# # for loops!

# %% [markdown]
#  // javascript
#  for (let i = 0; i< 20; i++){
#      console.log(i);
#  }

# %%
# in python, you have to iterate in a list. can't just move up from a number. and you indent instead of curly braces ("semantic whitespace")

for item in numbers: 
    print(item)
    print("hey!")
print("done!")
# Out:
# 5
# hey!
# 10
# hey!
# 15
# hey!
# 20
# hey!
# 25
# hey!
# done!

# %%
# input -> process -> output

# %%
new_numbers = []
for item in numbers:
    new_numbers.append(item*2)
new_numbers
# Out:
# [10, 20, 30, 40, 50]

# %%
if random.random()>0.5:
    print("heads up!")
else:
    print("tails :(")
# Out:
# tails :(

# %%
new_numbers = []
for item in numbers:
    if item >10:
        new_numbers.append(item)
new_numbers
# Out:
# [15, 20, 25]

# %%
[item for item in numbers if item >10]
# Out:
# [15, 20, 25]

# %%
# the above two are the same. for loop or list comprehension

# %%
for item in words:
    print(''.join([ch for ch in item if random.random() < 0.5]))
# Out:
# ot
# ca
# te
# ktte
# lack
# dot
#
# te
# cart
# bfre
# e
# hos
#
# h
# il
# on
# th
# he
# the
# l
# s
#
# o
# urt
# one
# i
# the
#
# i
#
# o
# thn
#
# in
# t
# h
# itng
#
# mre
# than
# y
# a
# e
# le
# e
# ct
# ou
# of
#
# b
#
# th
# bucke
# cos
#
# m
# d
#
# e
# rn
# th
# idniht
# ol
# e
# ae
# a
# fi
# i
#
# e
# bit
# t
# ue
# te
# lan
# in
# t
# m
# pill
# te
# an
# jp
# o
# th
# banago
# r
# ver
# spe
# ik
# h
# igs
# f
# ou
# of
# th
# fyig
# p
# d
# nto
# th
#
# tim
# ies
# whn
# yu
# avi
# fu
# t
# h
# hnd
# tha
# feds
# yo
#
# te
# r
# me
# yo
# cn't
# jud
#
# ok
#
# 's
# cv
#
# ol
# nn
# as
# t
#
# he
# chase
# '
# ou
# yu
# hkns
# beore
# th
# atch
# ek
#
# te
# v
# ok
# f
# y
# ap
# i'
# rnn
# ats
#
# os
# a
# tas
# f
# u
# o
# mece
# o
# tht
# bre
# en
# ou
# cme
#
# t
# ee
# cld
# ha
# a
# sile
# li
# yo
# c
# ead
#
# ors
# t
# war
# b
#
# n't
# mke
# hi
# dnk
# vriet
# is
# the
# ae
# of
# life
# oe
# i
#
# bue
# moon
# t
# me
# a
# og
# sr
# shr
# wa
# y
# e
# n
# yr
# leve
# keep
#
# al
# rli
#
# ng
# on
# h
# e
# akig
# n
# gsh
# a
# dle
# in
# a
# hay
# tp
# f
# t
# iebr
# o
# th
# ba
# pt
# a
# dme
#
# ze

# %% [markdown]
# # writing a program that generates acrostics

# %%
word = open("explainafewthings_neruda.txt").read().split()

# %%
p_words = [item for item in words if item.startswith("p")]
a_words = [item for item in words if item.startswith("a")]
b_words = [item for item in words if item.startswith("b")]
l_words = [item for item in words if item.startswith("l")]
o_words = [item for item in words if item.startswith("o")]

# %%
print(random.choice(p_words))
print(random.choice(a_words))
print(random.choice(b_words))
# Out:
# pot
# an
# bridge

# %% [markdown]
# too much repitition above, factor out

# %%
# what we need: data structure that allows us to create variables on the fly? dictionary

# %% [markdown]
# # dictionaries!
#
# acrostic  one word acrostic
#
# seed phrase: alison
# source text
#
# Abacus
# Leprechaun
# Lollopop
# Intelligence
# Sauna
# Opera
# Nighttimeb

# %%
planet_dist = {"Mercury": 0.387, "Venus": 0.723, "Earth": 1, "Mars": 1.523}
planet_dist
# Out:
# {'Mercury': 0.387, 'Venus': 0.723, 'Earth': 1, 'Mars': 1.523}

# %%
planet_dist["Mercury"]
# Out:
# 0.387

# %%
type(planet_dist)
# Out:
# dict

# %%
1 in planet_dist
# Out:
# False

# %%
planet_dist["Planet_X"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 planet_dist["Planet_X"]
#
# KeyError: 'Planet_X'

# %%
x = "Earth"
if x in planet_dist:
    print(planet_dist[x])
# Out:
# 1

# %%
planet_dist[3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 planet_dist[3]
#
# KeyError: 3

# %% [markdown]
# # values in dictionaries can be any type
# lists are ordered so you can do list[x] with x being a number
# dicts are not so you have to do dict["string"]

# %%
planet_moons = {
    "Mercury": [],
    "Venus": [],
    "Earth": ["Moon"],
    "Mars": ["Phobos","Deimos"],
    "Jupiter": ["Io","Europa","Ganymede","Callisto"]
}

# %%
type(planet_moons["Mercury"])
# Out:
# list

# %%
planet_moons["Mars"]
# Out:
# ['Phobos', 'Deimos']

# %%
planet_moons["Jupiter"][2]
# Out:
# 'Ganymede'

# %%
type(planet_moons)
# Out:
# dict

# %%
planet_moons[3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 planet_moons[3]
#
# KeyError: 3

# %%
planet_moons["Saturn"] = ["Titan","Enceladus"]

# %%
planet_moons
# Out:
# {'Mercury': [],
#  'Venus': [],
#  'Earth': ['Moon'],
#  'Mars': ['Phobos', 'Deimos'],
#  'Jupiter': ['Io', 'Europa', 'Ganymede', 'Callisto'],
#  'Saturn': ['Titan', 'Enceladus']}

# %%
x = [1,1,2,3,5]

# %%
x.append(8)

# %%
x
# Out:
# [1, 1, 2, 3, 5, 8]

# %%
planet_moons["Earth"].append("Allison")

# %%
planet_moons["Earth"]
# Out:
# ['Moon', 'Allison']

# %% [markdown]
# source text -> dictionary: keys are letters

# %%
text = open("explainafewthings_neruda.txt").read()

# %%
words = text.split()

# %%
initials = {}
for item in words:
    print(item[0])
    if item[0] in initials: # if initial letter item[0] exists, append this to them
        initials[item[0]].append(item)
    else: # if no key exists that is this letter make one
        initials[item[0]] = [item] 
    print(initials)
# Out:
# Y
# {'Y': ['You']}
# a
# {'Y': ['You'], 'a': ['are']}
# g
# {'Y': ['You'], 'a': ['are'], 'g': ['going']}
# t
# {'Y': ['You'], 'a': ['are'], 'g': ['going'], 't': ['to']}
# a
# {'Y': ['You'], 'a': ['are', 'ask:'], 'g': ['going'], 't': ['to']}
# a
# {'Y': ['You'], 'a': ['are', 'ask:', 'and'], 'g': ['going'], 't': ['to']}
# w
# {'Y': ['You'], 'a': ['are', 'ask:', 'and'], 'g': ['going'], 't': ['to'], 'w': ['where']}
# a
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are'], 'g': ['going'], 't': ['to'], 'w': ['where']}
# t
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are'], 'g': ['going'], 't': ['to', 'the'], 'w': ['where']}
# l
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are'], 'g': ['going'], 't': ['to', 'the'], 'w': ['where'], 'l': ['lilacs?']}
# a
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and'], 'g': ['going'], 't': ['to', 'the'], 'w': ['where'], 'l': ['lilacs?']}
# t
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and'], 'g': ['going'], 't': ['to', 'the', 'the'], 'w': ['where'], 'l': ['lilacs?']}
# p
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and'], 'g': ['going'], 't': ['to', 'the', 'the'], 'w': ['where'], 'l': ['lilacs?'], 'p': ['poppy-petalled']}
# m
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and'], 'g': ['going'], 't': ['to', 'the', 'the'], 'w': ['where'], 'l': ['lilacs?'], 'p': ['poppy-petalled'], 'm': ['metaphysics?']}
# a
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the'], 'w': ['where'], 'l': ['lilacs?'], 'p': ['poppy-petalled'], 'm': ['metaphysics?']}
# t
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the'], 'w': ['where'], 'l': ['lilacs?'], 'p': ['poppy-petalled'], 'm': ['metaphysics?']}
# r
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the'], 'w': ['where'], 'l': ['lilacs?'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain']}
# r
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the'], 'w': ['where'], 'l': ['lilacs?'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly']}
# s
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the'], 'w': ['where'], 'l': ['lilacs?'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering']}
# i
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the'], 'w': ['where'], 'l': ['lilacs?'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering'], 'i': ['its']}
# w
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the'], 'w': ['where', 'words'], 'l': ['lilacs?'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering'], 'i': ['its']}
# a
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the'], 'w': ['where', 'words'], 'l': ['lilacs?'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering'], 'i': ['its']}
# d
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the'], 'w': ['where', 'words'], 'l': ['lilacs?'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering'], 'i': ['its'], 'd': ['drilling']}
# t
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them'], 'w': ['where', 'words'], 'l': ['lilacs?'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering'], 'i': ['its'], 'd': ['drilling']}
# f
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them'], 'w': ['where', 'words'], 'l': ['lilacs?'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering'], 'i': ['its'], 'd': ['drilling'], 'f': ['full']}
# o
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them'], 'w': ['where', 'words'], 'l': ['lilacs?'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering'], 'i': ['its'], 'd': ['drilling'], 'f': ['full'], 'o': ['of']}
# a
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them'], 'w': ['where', 'words'], 'l': ['lilacs?'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering'], 'i': ['its'], 'd': ['drilling'], 'f': ['full'], 'o': ['of']}
# a
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them'], 'w': ['where', 'words'], 'l': ['lilacs?'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering'], 'i': ['its'], 'd': ['drilling'], 'f': ['full'], 'o': ['of']}
# b
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them'], 'w': ['where', 'words'], 'l': ['lilacs?'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering'], 'i': ['its'], 'd': ['drilling'], 'f': ['full'], 'o': ['of'], 'b': ['birds?']}
# I
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them'], 'w': ['where', 'words'], 'l': ['lilacs?'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering'], 'i': ['its'], 'd': ['drilling'], 'f': ['full'], 'o': ['of'], 'b': ['birds?'], 'I': ["I'll"]}
# t
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell'], 'w': ['where', 'words'], 'l': ['lilacs?'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering'], 'i': ['its'], 'd': ['drilling'], 'f': ['full'], 'o': ['of'], 'b': ['birds?'], 'I': ["I'll"]}
# y
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell'], 'w': ['where', 'words'], 'l': ['lilacs?'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering'], 'i': ['its'], 'd': ['drilling'], 'f': ['full'], 'o': ['of'], 'b': ['birds?'], 'I': ["I'll"], 'y': ['you']}
# a
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell'], 'w': ['where', 'words'], 'l': ['lilacs?'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering'], 'i': ['its'], 'd': ['drilling'], 'f': ['full'], 'o': ['of'], 'b': ['birds?'], 'I': ["I'll"], 'y': ['you']}
# t
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the'], 'w': ['where', 'words'], 'l': ['lilacs?'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering'], 'i': ['its'], 'd': ['drilling'], 'f': ['full'], 'o': ['of'], 'b': ['birds?'], 'I': ["I'll"], 'y': ['you']}
# n
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the'], 'w': ['where', 'words'], 'l': ['lilacs?'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering'], 'i': ['its'], 'd': ['drilling'], 'f': ['full'], 'o': ['of'], 'b': ['birds?'], 'I': ["I'll"], 'y': ['you'], 'n': ['news.']}
# I
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the'], 'w': ['where', 'words'], 'l': ['lilacs?'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering'], 'i': ['its'], 'd': ['drilling'], 'f': ['full'], 'o': ['of'], 'b': ['birds?'], 'I': ["I'll", 'I'], 'y': ['you'], 'n': ['news.']}
# l
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the'], 'w': ['where', 'words'], 'l': ['lilacs?', 'lived'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering'], 'i': ['its'], 'd': ['drilling'], 'f': ['full'], 'o': ['of'], 'b': ['birds?'], 'I': ["I'll", 'I'], 'y': ['you'], 'n': ['news.']}
# i
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the'], 'w': ['where', 'words'], 'l': ['lilacs?', 'lived'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering'], 'i': ['its', 'in'], 'd': ['drilling'], 'f': ['full'], 'o': ['of'], 'b': ['birds?'], 'I': ["I'll", 'I'], 'y': ['you'], 'n': ['news.']}
# a
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the'], 'w': ['where', 'words'], 'l': ['lilacs?', 'lived'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering'], 'i': ['its', 'in'], 'd': ['drilling'], 'f': ['full'], 'o': ['of'], 'b': ['birds?'], 'I': ["I'll", 'I'], 'y': ['you'], 'n': ['news.']}
# s
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the'], 'w': ['where', 'words'], 'l': ['lilacs?', 'lived'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,'], 'i': ['its', 'in'], 'd': ['drilling'], 'f': ['full'], 'o': ['of'], 'b': ['birds?'], 'I': ["I'll", 'I'], 'y': ['you'], 'n': ['news.']}
# a
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the'], 'w': ['where', 'words'], 'l': ['lilacs?', 'lived'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,'], 'i': ['its', 'in'], 'd': ['drilling'], 'f': ['full'], 'o': ['of'], 'b': ['birds?'], 'I': ["I'll", 'I'], 'y': ['you'], 'n': ['news.']}
# s
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the'], 'w': ['where', 'words'], 'l': ['lilacs?', 'lived'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling'], 'f': ['full'], 'o': ['of'], 'b': ['birds?'], 'I': ["I'll", 'I'], 'y': ['you'], 'n': ['news.']}
# o
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the'], 'w': ['where', 'words'], 'l': ['lilacs?', 'lived'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling'], 'f': ['full'], 'o': ['of', 'of'], 'b': ['birds?'], 'I': ["I'll", 'I'], 'y': ['you'], 'n': ['news.']}
# M
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the'], 'w': ['where', 'words'], 'l': ['lilacs?', 'lived'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling'], 'f': ['full'], 'o': ['of', 'of'], 'b': ['birds?'], 'I': ["I'll", 'I'], 'y': ['you'], 'n': ['news.'], 'M': ['Madrid,']}
# w
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the'], 'w': ['where', 'words', 'with'], 'l': ['lilacs?', 'lived'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling'], 'f': ['full'], 'o': ['of', 'of'], 'b': ['birds?'], 'I': ["I'll", 'I'], 'y': ['you'], 'n': ['news.'], 'M': ['Madrid,']}
# b
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the'], 'w': ['where', 'words', 'with'], 'l': ['lilacs?', 'lived'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling'], 'f': ['full'], 'o': ['of', 'of'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you'], 'n': ['news.'], 'M': ['Madrid,']}
# a
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the'], 'w': ['where', 'words', 'with'], 'l': ['lilacs?', 'lived'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling'], 'f': ['full'], 'o': ['of', 'of'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you'], 'n': ['news.'], 'M': ['Madrid,']}
# c
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the'], 'w': ['where', 'words', 'with'], 'l': ['lilacs?', 'lived'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling'], 'f': ['full'], 'o': ['of', 'of'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you'], 'n': ['news.'], 'M': ['Madrid,'], 'c': ['clocks,']}
# a
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the'], 'w': ['where', 'words', 'with'], 'l': ['lilacs?', 'lived'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling'], 'f': ['full'], 'o': ['of', 'of'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you'], 'n': ['news.'], 'M': ['Madrid,'], 'c': ['clocks,']}
# t
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.'], 'w': ['where', 'words', 'with'], 'l': ['lilacs?', 'lived'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling'], 'f': ['full'], 'o': ['of', 'of'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you'], 'n': ['news.'], 'M': ['Madrid,'], 'c': ['clocks,']}
# F
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.'], 'w': ['where', 'words', 'with'], 'l': ['lilacs?', 'lived'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling'], 'f': ['full'], 'o': ['of', 'of'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you'], 'n': ['news.'], 'M': ['Madrid,'], 'c': ['clocks,'], 'F': ['From']}
# t
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there'], 'w': ['where', 'words', 'with'], 'l': ['lilacs?', 'lived'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling'], 'f': ['full'], 'o': ['of', 'of'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you'], 'n': ['news.'], 'M': ['Madrid,'], 'c': ['clocks,'], 'F': ['From']}
# y
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there'], 'w': ['where', 'words', 'with'], 'l': ['lilacs?', 'lived'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling'], 'f': ['full'], 'o': ['of', 'of'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,'], 'c': ['clocks,'], 'F': ['From']}
# c
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there'], 'w': ['where', 'words', 'with'], 'l': ['lilacs?', 'lived'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling'], 'f': ['full'], 'o': ['of', 'of'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,'], 'c': ['clocks,', 'could'], 'F': ['From']}
# l
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there'], 'w': ['where', 'words', 'with'], 'l': ['lilacs?', 'lived', 'look'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling'], 'f': ['full'], 'o': ['of', 'of'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,'], 'c': ['clocks,', 'could'], 'F': ['From']}
# o
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there'], 'w': ['where', 'words', 'with'], 'l': ['lilacs?', 'lived', 'look'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling'], 'f': ['full'], 'o': ['of', 'of', 'out'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,'], 'c': ['clocks,', 'could'], 'F': ['From']}
# o
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there'], 'w': ['where', 'words', 'with'], 'l': ['lilacs?', 'lived', 'look'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling'], 'f': ['full'], 'o': ['of', 'of', 'out', 'over'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,'], 'c': ['clocks,', 'could'], 'F': ['From']}
# C
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there'], 'w': ['where', 'words', 'with'], 'l': ['lilacs?', 'lived', 'look'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling'], 'f': ['full'], 'o': ['of', 'of', 'out', 'over'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,'], 'c': ['clocks,', 'could'], 'F': ['From'], 'C': ["Castille's"]}
# d
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there'], 'w': ['where', 'words', 'with'], 'l': ['lilacs?', 'lived', 'look'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling', 'dry'], 'f': ['full'], 'o': ['of', 'of', 'out', 'over'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,'], 'c': ['clocks,', 'could'], 'F': ['From'], 'C': ["Castille's"]}
# f
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there'], 'w': ['where', 'words', 'with'], 'l': ['lilacs?', 'lived', 'look'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:'], 'o': ['of', 'of', 'out', 'over'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,'], 'c': ['clocks,', 'could'], 'F': ['From'], 'C': ["Castille's"]}
# a
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there'], 'w': ['where', 'words', 'with'], 'l': ['lilacs?', 'lived', 'look'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:'], 'o': ['of', 'of', 'out', 'over'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,'], 'c': ['clocks,', 'could'], 'F': ['From'], 'C': ["Castille's"]}
# l
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there'], 'w': ['where', 'words', 'with'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:'], 'o': ['of', 'of', 'out', 'over'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,'], 'c': ['clocks,', 'could'], 'F': ['From'], 'C': ["Castille's"]}
# o
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there'], 'w': ['where', 'words', 'with'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:'], 'o': ['of', 'of', 'out', 'over', 'ocean.'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,'], 'c': ['clocks,', 'could'], 'F': ['From'], 'C': ["Castille's"]}
# M
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there'], 'w': ['where', 'words', 'with'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:'], 'o': ['of', 'of', 'out', 'over', 'ocean.'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could'], 'F': ['From'], 'C': ["Castille's"]}
# h
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there'], 'w': ['where', 'words', 'with'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:'], 'o': ['of', 'of', 'out', 'over', 'ocean.'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house']}
# w
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there'], 'w': ['where', 'words', 'with', 'was'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:'], 'o': ['of', 'of', 'out', 'over', 'ocean.'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house']}
# c
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there'], 'w': ['where', 'words', 'with', 'was'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:'], 'o': ['of', 'of', 'out', 'over', 'ocean.'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house']}
# t
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:'], 'o': ['of', 'of', 'out', 'over', 'ocean.'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house']}
# h
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:'], 'o': ['of', 'of', 'out', 'over', 'ocean.'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house', 'house']}
# o
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house', 'house']}
# f
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:', 'flowers,'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of'], 'b': ['birds?', 'bells,'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house', 'house']}
# b
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:', 'flowers,'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of'], 'b': ['birds?', 'bells,', 'because'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house', 'house']}
# i
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in', 'in'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:', 'flowers,'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of'], 'b': ['birds?', 'bells,', 'because'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house', 'house']}
# e
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in', 'in'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:', 'flowers,'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of'], 'b': ['birds?', 'bells,', 'because'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house', 'house'], 'e': ['every']}
# c
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a'], 'g': ['going'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in', 'in'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:', 'flowers,'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of'], 'b': ['birds?', 'bells,', 'because'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called', 'cranny'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house', 'house'], 'e': ['every']}
# g
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a'], 'g': ['going', 'geraniums'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in', 'in'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:', 'flowers,'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of'], 'b': ['birds?', 'bells,', 'because'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called', 'cranny'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house', 'house'], 'e': ['every']}
# b
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a'], 'g': ['going', 'geraniums'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in', 'in'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:', 'flowers,'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of'], 'b': ['birds?', 'bells,', 'because', 'burst:'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called', 'cranny'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house', 'house'], 'e': ['every']}
# i
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a'], 'g': ['going', 'geraniums'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in', 'in', 'it'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:', 'flowers,'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of'], 'b': ['birds?', 'bells,', 'because', 'burst:'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called', 'cranny'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house', 'house'], 'e': ['every']}
# w
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a'], 'g': ['going', 'geraniums'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was', 'was'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in', 'in', 'it'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:', 'flowers,'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of'], 'b': ['birds?', 'bells,', 'because', 'burst:'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called', 'cranny'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house', 'house'], 'e': ['every']}
# a
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a', 'a'], 'g': ['going', 'geraniums'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was', 'was'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in', 'in', 'it'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:', 'flowers,'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of'], 'b': ['birds?', 'bells,', 'because', 'burst:'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called', 'cranny'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house', 'house'], 'e': ['every']}
# g
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a', 'a'], 'g': ['going', 'geraniums', 'good-looking'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was', 'was'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in', 'in', 'it'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:', 'flowers,'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of'], 'b': ['birds?', 'bells,', 'because', 'burst:'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called', 'cranny'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house', 'house'], 'e': ['every']}
# h
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a', 'a'], 'g': ['going', 'geraniums', 'good-looking'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was', 'was'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in', 'in', 'it'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:', 'flowers,'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of'], 'b': ['birds?', 'bells,', 'because', 'burst:'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called', 'cranny'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house', 'house', 'house'], 'e': ['every']}
# w
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a', 'a'], 'g': ['going', 'geraniums', 'good-looking'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was', 'was', 'with'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in', 'in', 'it'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:', 'flowers,'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of'], 'b': ['birds?', 'bells,', 'because', 'burst:'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called', 'cranny'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house', 'house', 'house'], 'e': ['every']}
# i
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a', 'a'], 'g': ['going', 'geraniums', 'good-looking'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was', 'was', 'with'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in', 'in', 'it', 'its'], 'd': ['drilling', 'dry'], 'f': ['full', 'face:', 'flowers,'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of'], 'b': ['birds?', 'bells,', 'because', 'burst:'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called', 'cranny'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house', 'house', 'house'], 'e': ['every']}
# d
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a', 'a'], 'g': ['going', 'geraniums', 'good-looking'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was', 'was', 'with'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in', 'in', 'it', 'its'], 'd': ['drilling', 'dry', 'dogs'], 'f': ['full', 'face:', 'flowers,'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of'], 'b': ['birds?', 'bells,', 'because', 'burst:'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called', 'cranny'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house', 'house', 'house'], 'e': ['every']}
# a
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a', 'a', 'and'], 'g': ['going', 'geraniums', 'good-looking'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was', 'was', 'with'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in', 'in', 'it', 'its'], 'd': ['drilling', 'dry', 'dogs'], 'f': ['full', 'face:', 'flowers,'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of'], 'b': ['birds?', 'bells,', 'because', 'burst:'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called', 'cranny'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house', 'house', 'house'], 'e': ['every']}
# c
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a', 'a', 'and'], 'g': ['going', 'geraniums', 'good-looking'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was', 'was', 'with'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in', 'in', 'it', 'its'], 'd': ['drilling', 'dry', 'dogs'], 'f': ['full', 'face:', 'flowers,'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of'], 'b': ['birds?', 'bells,', 'because', 'burst:'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called', 'cranny', 'children.'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house', 'house', 'house'], 'e': ['every']}
# R
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a', 'a', 'and'], 'g': ['going', 'geraniums', 'good-looking'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was', 'was', 'with'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in', 'in', 'it', 'its'], 'd': ['drilling', 'dry', 'dogs'], 'f': ['full', 'face:', 'flowers,'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of'], 'b': ['birds?', 'bells,', 'because', 'burst:'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called', 'cranny', 'children.'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house', 'house', 'house'], 'e': ['every'], 'R': ['Remember,']}
# R
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a', 'a', 'and'], 'g': ['going', 'geraniums', 'good-looking'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was', 'was', 'with'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in', 'in', 'it', 'its'], 'd': ['drilling', 'dry', 'dogs'], 'f': ['full', 'face:', 'flowers,'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of'], 'b': ['birds?', 'bells,', 'because', 'burst:'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called', 'cranny', 'children.'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house', 'house', 'house'], 'e': ['every'], 'R': ['Remember,', 'Raul?']}
# E
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a', 'a', 'and'], 'g': ['going', 'geraniums', 'good-looking'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was', 'was', 'with'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in', 'in', 'it', 'its'], 'd': ['drilling', 'dry', 'dogs'], 'f': ['full', 'face:', 'flowers,'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of'], 'b': ['birds?', 'bells,', 'because', 'burst:'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called', 'cranny', 'children.'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house', 'house', 'house'], 'e': ['every'], 'R': ['Remember,', 'Raul?'], 'E': ['Eh,']}
# R
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a', 'a', 'and'], 'g': ['going', 'geraniums', 'good-looking'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the'], 'w': ['where', 'words', 'with', 'was', 'was', 'with'], 'l': ['lilacs?', 'lived', 'look', 'leather'], 'p': ['poppy-petalled'], 'm': ['metaphysics?'], 'r': ['rain', 'repeatedly'], 's': ['spattering', 'suburb,', 'suburb'], 'i': ['its', 'in', 'in', 'it', 'its'], 'd': ['drilling', 'dry', 'dogs'], 'f': ['full', 'face:', 'flowers,'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of'], 'b': ['birds?', 'bells,', 'because', 'burst:'], 'I': ["I'll", 'I'], 'y': ['you', 'you'], 'n': ['news.'], 'M': ['Madrid,', 'My'], 'c': ['clocks,', 'could', 'called', 'cranny', 'children.'], 'F': ['From'], 'C': ["Castille's"], 'h': ['house', 'house', 'house'], 'e': ['every'], 'R': ['Remember,', 'Raul?', 'Rafel?'], 'E': ['Eh,']}
# F
# ...
# b
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a', 'a', 'and', 'a', 'a', 'a', 'and', 'a', 'all', 'and', 'and', 'and', 'and', 'and', 'and', 'abominate!', 'a', 'and', 'at', 'and', 'a', 'and', 'are', 'ask:', 'and', 'and', 'and', 'and', 'and'], 'g': ['going', 'geraniums', 'good-looking', 'ground', 'gunpowder', 'generals:', 'great'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'texture', 'the', 'the', 'tomatoes', 'the', 'that', 'the', 'the', 'then', 'then', 'then', 'through', 'the', 'to', 'the', 'through', 'the', 'that', 'the', 'that', 'the', 'thistle', 'that', 'the', 'to', 'the', 'tower', 'tide', 'to', 'the', 'the', 'the', 'the', 'the', 'the'], 'w': ['where', 'words', 'with', 'was', 'was', 'with', 'which', 'with', 'with', 'with', 'which', 'weather', 'wave', 'wave', 'was', 'with', 'with', 'with', 'without', 'would', 'would', 'would', 'with', 'wave', 'with', 'which', 'will', 'why'], 'l': ['lilacs?', 'lived', 'look', 'leather', 'light', 'loud', 'like', 'litres,', 'life,', 'leapt', 'like', 'like', 'look', 'leaves', 'land?'], 'p': ['poppy-petalled', 'pile-ups', 'palpitating', 'potatoes,', 'planes', 'pride', 'poetry'], 'm': ['metaphysics?', 'my', 'mouth?', 'my', 'merchandises,', 'my', 'metres,', 'measure', 'morning', 'morning', 'my', 'metal'], 'r': ['rain', 'repeatedly', 'remember', 'roofs', 'rolling', 'ran', 'rifle'], 's': ['spattering', 'suburb,', 'suburb', 'salt', 'stalls', 'suburb', 'statue', 'swirl', 'spoons,', 'swelled', 'streets,', 'sharp', 'stacked-up', 'sun', 'sea.', 'spattering', 'sky', 'streets', 'stones', 'spit', 'seen', 'see', 'socket', 'speak', 'see', 'streets.', 'see', 'streets.', 'see'], 'i': ['its', 'in', 'in', 'it', 'its', 'in', 'its', 'inkwell', 'in', 'into', 'in', 'in', 'ivory', 'in', 'instead', 'in', 'in'], 'd': ['drilling', 'dry', 'dogs', 'do', 'drowned', 'drained', 'deep', 'down', 'devouring', 'duchesses,', 'despise,', 'dry', 'drown', 'dead', 'dead', 'day', "doesn't", 'dreams'], 'f': ['full', 'face:', 'flowers,', 'from', 'flowers', 'flowed', 'feet', 'fish,', 'falters,', 'fine,', 'frenzied', 'from', 'fire,', 'from', 'from', 'finger-rings', 'friars', 'fuss,', 'face', 'from', 'flows', 'flowers,', 'from', 'from', 'from', 'find'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of', 'on', 'of', 'of', 'of', 'of', 'of', 'of', 'oil', 'of', 'of', 'of', 'of', 'on', 'of', 'one', 'one', 'out', 'of', 'on', 'on,', 'on', 'of', 'on', 'out,', 'of', 'one', 'of', 'of', 'of', 'one', 'of', 'of', 'of'], 'b': ['birds?', 'bells,', 'because', 'burst:', 'balconies', 'brother!', 'big', 'bread,', 'baying', 'burning,', 'bonfires', 'beings', 'blood.', 'bandits', 'bandits', 'black', 'blessings', 'blood', 'blood.', 'bite', 'blood', 'broken', 'burning', 'bullets', 'born', "bull's", 'blood', 'blood', 'blood'], 'I': ["I'll", 'I', 'I'], 'y': ['you', 'you', 'you', 'your', 'you', 'you', 'your', "you'll"], 'n': ['news.', 'native'], 'M': ['Madrid,', 'My', 'Moors,'], 'c': ['clocks,', 'could', 'called', 'cranny', 'children.', 'cold', 'came', 'children', 'children', "children's", 'child', 'crime'], 'F': ['From', 'Federico,', 'Face'], 'C': ["Castille's", 'Come', 'Come', 'Come'], 'h': ['house', 'house', 'house', 'hake:', 'hands', 'human', 'have', 'house,', 'house', 'hearts.', 'his', 'his'], 'e': ['every', 'earth', 'every', 'every', 'emerges', 'every', 'eyes,', 'every', 'eye'], 'R': ['Remember,', 'Raul?', 'Rafel?'], 'E': ['Eh,', 'Everything'], 'u': ['under'], 'J': ['June', 'Jackals'], 'B': ['Brother,', 'Bandits'], 'v': ['voices,', 'vane', 'vipers', 'vipers', 'volcanoes'], 'A': ['Arguelles', 'And', 'And'], 'â': ['â€”'], 'k': ['kill', 'knives!'], 'j': ['jackals'], 'S': ['Spain', 'Spain', 'Spain', 'Spain'], 'T': ['Treacherous', 'The'], ':': [':']}
# I
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a', 'a', 'and', 'a', 'a', 'a', 'and', 'a', 'all', 'and', 'and', 'and', 'and', 'and', 'and', 'abominate!', 'a', 'and', 'at', 'and', 'a', 'and', 'are', 'ask:', 'and', 'and', 'and', 'and', 'and'], 'g': ['going', 'geraniums', 'good-looking', 'ground', 'gunpowder', 'generals:', 'great'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'texture', 'the', 'the', 'tomatoes', 'the', 'that', 'the', 'the', 'then', 'then', 'then', 'through', 'the', 'to', 'the', 'through', 'the', 'that', 'the', 'that', 'the', 'thistle', 'that', 'the', 'to', 'the', 'tower', 'tide', 'to', 'the', 'the', 'the', 'the', 'the', 'the'], 'w': ['where', 'words', 'with', 'was', 'was', 'with', 'which', 'with', 'with', 'with', 'which', 'weather', 'wave', 'wave', 'was', 'with', 'with', 'with', 'without', 'would', 'would', 'would', 'with', 'wave', 'with', 'which', 'will', 'why'], 'l': ['lilacs?', 'lived', 'look', 'leather', 'light', 'loud', 'like', 'litres,', 'life,', 'leapt', 'like', 'like', 'look', 'leaves', 'land?'], 'p': ['poppy-petalled', 'pile-ups', 'palpitating', 'potatoes,', 'planes', 'pride', 'poetry'], 'm': ['metaphysics?', 'my', 'mouth?', 'my', 'merchandises,', 'my', 'metres,', 'measure', 'morning', 'morning', 'my', 'metal'], 'r': ['rain', 'repeatedly', 'remember', 'roofs', 'rolling', 'ran', 'rifle'], 's': ['spattering', 'suburb,', 'suburb', 'salt', 'stalls', 'suburb', 'statue', 'swirl', 'spoons,', 'swelled', 'streets,', 'sharp', 'stacked-up', 'sun', 'sea.', 'spattering', 'sky', 'streets', 'stones', 'spit', 'seen', 'see', 'socket', 'speak', 'see', 'streets.', 'see', 'streets.', 'see'], 'i': ['its', 'in', 'in', 'it', 'its', 'in', 'its', 'inkwell', 'in', 'into', 'in', 'in', 'ivory', 'in', 'instead', 'in', 'in'], 'd': ['drilling', 'dry', 'dogs', 'do', 'drowned', 'drained', 'deep', 'down', 'devouring', 'duchesses,', 'despise,', 'dry', 'drown', 'dead', 'dead', 'day', "doesn't", 'dreams'], 'f': ['full', 'face:', 'flowers,', 'from', 'flowers', 'flowed', 'feet', 'fish,', 'falters,', 'fine,', 'frenzied', 'from', 'fire,', 'from', 'from', 'finger-rings', 'friars', 'fuss,', 'face', 'from', 'flows', 'flowers,', 'from', 'from', 'from', 'find'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of', 'on', 'of', 'of', 'of', 'of', 'of', 'of', 'oil', 'of', 'of', 'of', 'of', 'on', 'of', 'one', 'one', 'out', 'of', 'on', 'on,', 'on', 'of', 'on', 'out,', 'of', 'one', 'of', 'of', 'of', 'one', 'of', 'of', 'of'], 'b': ['birds?', 'bells,', 'because', 'burst:', 'balconies', 'brother!', 'big', 'bread,', 'baying', 'burning,', 'bonfires', 'beings', 'blood.', 'bandits', 'bandits', 'black', 'blessings', 'blood', 'blood.', 'bite', 'blood', 'broken', 'burning', 'bullets', 'born', "bull's", 'blood', 'blood', 'blood'], 'I': ["I'll", 'I', 'I', 'In'], 'y': ['you', 'you', 'you', 'your', 'you', 'you', 'your', "you'll"], 'n': ['news.', 'native'], 'M': ['Madrid,', 'My', 'Moors,'], 'c': ['clocks,', 'could', 'called', 'cranny', 'children.', 'cold', 'came', 'children', 'children', "children's", 'child', 'crime'], 'F': ['From', 'Federico,', 'Face'], 'C': ["Castille's", 'Come', 'Come', 'Come'], 'h': ['house', 'house', 'house', 'hake:', 'hands', 'human', 'have', 'house,', 'house', 'hearts.', 'his', 'his'], 'e': ['every', 'earth', 'every', 'every', 'emerges', 'every', 'eyes,', 'every', 'eye'], 'R': ['Remember,', 'Raul?', 'Rafel?'], 'E': ['Eh,', 'Everything'], 'u': ['under'], 'J': ['June', 'Jackals'], 'B': ['Brother,', 'Bandits'], 'v': ['voices,', 'vane', 'vipers', 'vipers', 'volcanoes'], 'A': ['Arguelles', 'And', 'And'], 'â': ['â€”'], 'k': ['kill', 'knives!'], 'j': ['jackals'], 'S': ['Spain', 'Spain', 'Spain', 'Spain'], 'T': ['Treacherous', 'The'], ':': [':']}
# t
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a', 'a', 'and', 'a', 'a', 'a', 'and', 'a', 'all', 'and', 'and', 'and', 'and', 'and', 'and', 'abominate!', 'a', 'and', 'at', 'and', 'a', 'and', 'are', 'ask:', 'and', 'and', 'and', 'and', 'and'], 'g': ['going', 'geraniums', 'good-looking', 'ground', 'gunpowder', 'generals:', 'great'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'texture', 'the', 'the', 'tomatoes', 'the', 'that', 'the', 'the', 'then', 'then', 'then', 'through', 'the', 'to', 'the', 'through', 'the', 'that', 'the', 'that', 'the', 'thistle', 'that', 'the', 'to', 'the', 'tower', 'tide', 'to', 'the', 'the', 'the', 'the', 'the', 'the', 'the'], 'w': ['where', 'words', 'with', 'was', 'was', 'with', 'which', 'with', 'with', 'with', 'which', 'weather', 'wave', 'wave', 'was', 'with', 'with', 'with', 'without', 'would', 'would', 'would', 'with', 'wave', 'with', 'which', 'will', 'why'], 'l': ['lilacs?', 'lived', 'look', 'leather', 'light', 'loud', 'like', 'litres,', 'life,', 'leapt', 'like', 'like', 'look', 'leaves', 'land?'], 'p': ['poppy-petalled', 'pile-ups', 'palpitating', 'potatoes,', 'planes', 'pride', 'poetry'], 'm': ['metaphysics?', 'my', 'mouth?', 'my', 'merchandises,', 'my', 'metres,', 'measure', 'morning', 'morning', 'my', 'metal'], 'r': ['rain', 'repeatedly', 'remember', 'roofs', 'rolling', 'ran', 'rifle'], 's': ['spattering', 'suburb,', 'suburb', 'salt', 'stalls', 'suburb', 'statue', 'swirl', 'spoons,', 'swelled', 'streets,', 'sharp', 'stacked-up', 'sun', 'sea.', 'spattering', 'sky', 'streets', 'stones', 'spit', 'seen', 'see', 'socket', 'speak', 'see', 'streets.', 'see', 'streets.', 'see'], 'i': ['its', 'in', 'in', 'it', 'its', 'in', 'its', 'inkwell', 'in', 'into', 'in', 'in', 'ivory', 'in', 'instead', 'in', 'in'], 'd': ['drilling', 'dry', 'dogs', 'do', 'drowned', 'drained', 'deep', 'down', 'devouring', 'duchesses,', 'despise,', 'dry', 'drown', 'dead', 'dead', 'day', "doesn't", 'dreams'], 'f': ['full', 'face:', 'flowers,', 'from', 'flowers', 'flowed', 'feet', 'fish,', 'falters,', 'fine,', 'frenzied', 'from', 'fire,', 'from', 'from', 'finger-rings', 'friars', 'fuss,', 'face', 'from', 'flows', 'flowers,', 'from', 'from', 'from', 'find'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of', 'on', 'of', 'of', 'of', 'of', 'of', 'of', 'oil', 'of', 'of', 'of', 'of', 'on', 'of', 'one', 'one', 'out', 'of', 'on', 'on,', 'on', 'of', 'on', 'out,', 'of', 'one', 'of', 'of', 'of', 'one', 'of', 'of', 'of'], 'b': ['birds?', 'bells,', 'because', 'burst:', 'balconies', 'brother!', 'big', 'bread,', 'baying', 'burning,', 'bonfires', 'beings', 'blood.', 'bandits', 'bandits', 'black', 'blessings', 'blood', 'blood.', 'bite', 'blood', 'broken', 'burning', 'bullets', 'born', "bull's", 'blood', 'blood', 'blood'], 'I': ["I'll", 'I', 'I', 'In'], 'y': ['you', 'you', 'you', 'your', 'you', 'you', 'your', "you'll"], 'n': ['news.', 'native'], 'M': ['Madrid,', 'My', 'Moors,'], 'c': ['clocks,', 'could', 'called', 'cranny', 'children.', 'cold', 'came', 'children', 'children', "children's", 'child', 'crime'], 'F': ['From', 'Federico,', 'Face'], 'C': ["Castille's", 'Come', 'Come', 'Come'], 'h': ['house', 'house', 'house', 'hake:', 'hands', 'human', 'have', 'house,', 'house', 'hearts.', 'his', 'his'], 'e': ['every', 'earth', 'every', 'every', 'emerges', 'every', 'eyes,', 'every', 'eye'], 'R': ['Remember,', 'Raul?', 'Rafel?'], 'E': ['Eh,', 'Everything'], 'u': ['under'], 'J': ['June', 'Jackals'], 'B': ['Brother,', 'Bandits'], 'v': ['voices,', 'vane', 'vipers', 'vipers', 'volcanoes'], 'A': ['Arguelles', 'And', 'And'], 'â': ['â€”'], 'k': ['kill', 'knives!'], 'j': ['jackals'], 'S': ['Spain', 'Spain', 'Spain', 'Spain'], 'T': ['Treacherous', 'The'], ':': [':']}
# s
# {'Y': ['You'], 'a': ['are', 'ask:', 'and', 'are', 'and', 'and', 'and', 'apertures', 'and', 'all', 'a', 'a', 'and', 'and', 'a', 'a', 'and', 'a', 'a', 'a', 'and', 'a', 'all', 'and', 'and', 'and', 'and', 'and', 'and', 'abominate!', 'a', 'and', 'at', 'and', 'a', 'and', 'are', 'ask:', 'and', 'and', 'and', 'and', 'and'], 'g': ['going', 'geraniums', 'good-looking', 'ground', 'gunpowder', 'generals:', 'great'], 't': ['to', 'the', 'the', 'the', 'them', 'tell', 'the', 'trees.', 'there', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'texture', 'the', 'the', 'tomatoes', 'the', 'that', 'the', 'the', 'then', 'then', 'then', 'through', 'the', 'to', 'the', 'through', 'the', 'that', 'the', 'that', 'the', 'thistle', 'that', 'the', 'to', 'the', 'tower', 'tide', 'to', 'the', 'the', 'the', 'the', 'the', 'the', 'the'], 'w': ['where', 'words', 'with', 'was', 'was', 'with', 'which', 'with', 'with', 'with', 'which', 'weather', 'wave', 'wave', 'was', 'with', 'with', 'with', 'without', 'would', 'would', 'would', 'with', 'wave', 'with', 'which', 'will', 'why'], 'l': ['lilacs?', 'lived', 'look', 'leather', 'light', 'loud', 'like', 'litres,', 'life,', 'leapt', 'like', 'like', 'look', 'leaves', 'land?'], 'p': ['poppy-petalled', 'pile-ups', 'palpitating', 'potatoes,', 'planes', 'pride', 'poetry'], 'm': ['metaphysics?', 'my', 'mouth?', 'my', 'merchandises,', 'my', 'metres,', 'measure', 'morning', 'morning', 'my', 'metal'], 'r': ['rain', 'repeatedly', 'remember', 'roofs', 'rolling', 'ran', 'rifle'], 's': ['spattering', 'suburb,', 'suburb', 'salt', 'stalls', 'suburb', 'statue', 'swirl', 'spoons,', 'swelled', 'streets,', 'sharp', 'stacked-up', 'sun', 'sea.', 'spattering', 'sky', 'streets', 'stones', 'spit', 'seen', 'see', 'socket', 'speak', 'see', 'streets.', 'see', 'streets.', 'see', 'streets!'], 'i': ['its', 'in', 'in', 'it', 'its', 'in', 'its', 'inkwell', 'in', 'into', 'in', 'in', 'ivory', 'in', 'instead', 'in', 'in'], 'd': ['drilling', 'dry', 'dogs', 'do', 'drowned', 'drained', 'deep', 'down', 'devouring', 'duchesses,', 'despise,', 'dry', 'drown', 'dead', 'dead', 'day', "doesn't", 'dreams'], 'f': ['full', 'face:', 'flowers,', 'from', 'flowers', 'flowed', 'feet', 'fish,', 'falters,', 'fine,', 'frenzied', 'from', 'fire,', 'from', 'from', 'finger-rings', 'friars', 'fuss,', 'face', 'from', 'flows', 'flowers,', 'from', 'from', 'from', 'find'], 'o': ['of', 'of', 'out', 'over', 'ocean.', 'of', 'on', 'of', 'of', 'of', 'of', 'of', 'of', 'oil', 'of', 'of', 'of', 'of', 'on', 'of', 'one', 'one', 'out', 'of', 'on', 'on,', 'on', 'of', 'on', 'out,', 'of', 'one', 'of', 'of', 'of', 'one', 'of', 'of', 'of'], 'b': ['birds?', 'bells,', 'because', 'burst:', 'balconies', 'brother!', 'big', 'bread,', 'baying', 'burning,', 'bonfires', 'beings', 'blood.', 'bandits', 'bandits', 'black', 'blessings', 'blood', 'blood.', 'bite', 'blood', 'broken', 'burning', 'bullets', 'born', "bull's", 'blood', 'blood', 'blood'], 'I': ["I'll", 'I', 'I', 'In'], 'y': ['you', 'you', 'you', 'your', 'you', 'you', 'your', "you'll"], 'n': ['news.', 'native'], 'M': ['Madrid,', 'My', 'Moors,'], 'c': ['clocks,', 'could', 'called', 'cranny', 'children.', 'cold', 'came', 'children', 'children', "children's", 'child', 'crime'], 'F': ['From', 'Federico,', 'Face'], 'C': ["Castille's", 'Come', 'Come', 'Come'], 'h': ['house', 'house', 'house', 'hake:', 'hands', 'human', 'have', 'house,', 'house', 'hearts.', 'his', 'his'], 'e': ['every', 'earth', 'every', 'every', 'emerges', 'every', 'eyes,', 'every', 'eye'], 'R': ['Remember,', 'Raul?', 'Rafel?'], 'E': ['Eh,', 'Everything'], 'u': ['under'], 'J': ['June', 'Jackals'], 'B': ['Brother,', 'Bandits'], 'v': ['voices,', 'vane', 'vipers', 'vipers', 'volcanoes'], 'A': ['Arguelles', 'And', 'And'], 'â': ['â€”'], 'k': ['kill', 'knives!'], 'j': ['jackals'], 'S': ['Spain', 'Spain', 'Spain', 'Spain'], 'T': ['Treacherous', 'The'], ':': [':']}

# %%
print(len(initials))
# Out:
# 37

# %%
initials
# Out:
# {'Y': ['You'],
#  'a': ['are',
#   'ask:',
#   'and',
#   'are',
#   'and',
#   'and',
#   'and',
#   'apertures',
#   'and',
#   'all',
#   'a',
#   'a',
#   'and',
#   'and',
#   'a',
#   'a',
#   'and',
#   'a',
#   'a',
#   'a',
#   'and',
#   'a',
#   'all',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and',
#   'abominate!',
#   'a',
#   'and',
#   'at',
#   'and',
#   'a',
#   'and',
#   'are',
#   'ask:',
#   'and',
#   'and',
#   'and',
#   'and',
#   'and'],
#  'g': ['going',
#   'geraniums',
#   'good-looking',
#   'ground',
#   'gunpowder',
#   'generals:',
#   'great'],
#  't': ['to',
#   'the',
#   'the',
#   'the',
#   'them',
#   'tell',
#   'the',
#   'trees.',
#   'there',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'texture',
#   'the',
#   'the',
#   'tomatoes',
#   'the',
#   'that',
#   'the',
#   'the',
#   'then',
#   'then',
#   'then',
#   'through',
#   'the',
#   'to',
#   'the',
#   'through',
#   'the',
#   'that',
#   'the',
#   'that',
#   'the',
#   'thistle',
#   'that',
#   'the',
#   'to',
#   'the',
#   'tower',
#   'tide',
#   'to',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the'],
#  'w': ['where',
#   'words',
#   'with',
#   'was',
#   'was',
#   'with',
#   'which',
#   'with',
#   'with',
#   'with',
#   'which',
#   'weather',
#   'wave',
#   'wave',
#   'was',
#   'with',
#   'with',
#   'with',
#   'without',
#   'would',
#   'would',
#   'would',
#   'with',
#   'wave',
#   'with',
#   'which',
#   'will',
#   'why'],
#  'l': ['lilacs?',
#   'lived',
#   'look',
#   'leather',
#   'light',
#   'loud',
#   'like',
#   'litres,',
#   'life,',
#   'leapt',
#   'like',
#   'like',
#   'look',
#   'leaves',
#   'land?'],
#  'p': ['poppy-petalled',
#   'pile-ups',
#   'palpitating',
#   'potatoes,',
#   'planes',
#   'pride',
#   'poetry'],
#  'm': ['metaphysics?',
#   'my',
#   'mouth?',
#   'my',
#   'merchandises,',
#   'my',
#   'metres,',
#   'measure',
#   'morning',
#   'morning',
#   'my',
#   'metal'],
#  'r': ['rain', 'repeatedly', 'remember', 'roofs', 'rolling', 'ran', 'rifle'],
#  's': ['spattering',
#   'suburb,',
#   'suburb',
#   'salt',
#   'stalls',
#   'suburb',
#   'statue',
#   'swirl',
#   'spoons,',
#   'swelled',
#   'streets,',
#   'sharp',
#   'stacked-up',
#   'sun',
#   'sea.',
#   'spattering',
#   'sky',
#   'streets',
#   'stones',
#   'spit',
#   'seen',
#   'see',
#   'socket',
#   'speak',
#   'see',
#   'streets.',
#   'see',
#   'streets.',
#   'see',
#   'streets!'],
#  'i': ['its',
#   'in',
#   'in',
#   'it',
#   'its',
#   'in',
#   'its',
#   'inkwell',
#   'in',
#   'into',
#   'in',
#   'in',
#   'ivory',
#   'in',
#   'instead',
#   'in',
#   'in'],
#  'd': ['drilling',
#   'dry',
#   'dogs',
#   'do',
#   'drowned',
#   'drained',
#   'deep',
#   'down',
#   'devouring',
#   'duchesses,',
#   'despise,',
#   'dry',
#   'drown',
#   'dead',
#   'dead',
#   'day',
#   "doesn't",
#   'dreams'],
#  'f': ['full',
#   'face:',
#   'flowers,',
#   'from',
#   'flowers',
#   'flowed',
#   'feet',
#   'fish,',
#   'falters,',
#   'fine,',
#   'frenzied',
#   'from',
#   'fire,',
#   'from',
#   'from',
#   'finger-rings',
#   'friars',
#   'fuss,',
#   'face',
#   'from',
#   'flows',
#   'flowers,',
#   'from',
#   'from',
#   'from',
#   'find'],
#  'o': ['of',
#   'of',
#   'out',
#   'over',
#   'ocean.',
#   'of',
#   'on',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'oil',
#   'of',
#   'of',
#   'of',
#   'of',
#   'on',
#   'of',
#   'one',
#   'one',
#   'out',
#   'of',
#   'on',
#   'on,',
#   'on',
#   'of',
#   'on',
#   'out,',
#   'of',
#   'one',
#   'of',
#   'of',
#   'of',
#   'one',
#   'of',
#   'of',
#   'of'],
#  'b': ['birds?',
#   'bells,',
#   'because',
#   'burst:',
#   'balconies',
#   'brother!',
#   'big',
#   'bread,',
#   'baying',
#   'burning,',
#   'bonfires',
#   'beings',
#   'blood.',
#   'bandits',
#   'bandits',
#   'black',
#   'blessings',
#   'blood',
#   'blood.',
#   'bite',
#   'blood',
#   'broken',
#   'burning',
#   'bullets',
#   'born',
#   "bull's",
#   'blood',
#   'blood',
#   'blood'],
#  'I': ["I'll", 'I', 'I', 'In'],
#  'y': ['you', 'you', 'you', 'your', 'you', 'you', 'your', "you'll"],
#  'n': ['news.', 'native'],
#  'M': ['Madrid,', 'My', 'Moors,'],
#  'c': ['clocks,',
#   'could',
#   'called',
#   'cranny',
#   'children.',
#   'cold',
#   'came',
#   'children',
#   'children',
#   "children's",
#   'child',
#   'crime'],
#  'F': ['From', 'Federico,', 'Face'],
#  'C': ["Castille's", 'Come', 'Come', 'Come'],
#  'h': ['house',
#   'house',
#   'house',
#   'hake:',
#   'hands',
#   'human',
#   'have',
#   'house,',
#   'house',
#   'hearts.',
#   'his',
#   'his'],
#  'e': ['every',
#   'earth',
#   'every',
#   'every',
#   'emerges',
#   'every',
#   'eyes,',
#   'every',
#   'eye'],
#  'R': ['Remember,', 'Raul?', 'Rafel?'],
#  'E': ['Eh,', 'Everything'],
#  'u': ['under'],
#  'J': ['June', 'Jackals'],
#  'B': ['Brother,', 'Bandits'],
#  'v': ['voices,', 'vane', 'vipers', 'vipers', 'volcanoes'],
#  'A': ['Arguelles', 'And', 'And'],
#  'â': ['â€”'],
#  'k': ['kill', 'knives!'],
#  'j': ['jackals'],
#  'S': ['Spain', 'Spain', 'Spain', 'Spain'],
#  'T': ['Treacherous', 'The'],
#  ':': [':']}

# %%
import random
seed = "florafauna" # this is the seed you put in
for item in seed:
    if item not in initials:
        print("ACROSTIC ERROR! DANGER!!!")
    else:
        print(random.choice(initials[item]))
# Out:
# frenzied
# like
# of
# ran
# a
# fuss,
# all
# under
# news.
# and

# %%
for item in initials.items():
    print(item[0], len(item[1]))
# Out:
# Y 1
# a 43
# g 7
# t 53
# w 28
# l 15
# p 7
# m 12
# r 7
# s 30
# i 17
# d 18
# f 26
# o 39
# b 29
# I 4
# y 8
# n 2
# M 3
# c 12
# F 3
# C 4
# h 12
# e 9
# R 3
# E 2
# u 1
# J 2
# B 2
# v 5
# A 3
# â 1
# k 2
# j 1
# S 4
# T 2
# : 1

# %%
import sys
# !{sys.executable} -m pip install tracery
# Out:
# Requirement already satisfied: tracery in c:\users\weber\anaconda3\lib\site-packages (0.1.1)

# %%
import tracery

# %%
rules = {
    "origin": "#greeting#, #noun#!", # anything not inside pound signs is copied verbatim!
    "noun": ["galaxy", "world", "solar system", "nebula"],
    "greeting": ["Howdy", "greetings", "zoinks", "wsup"]
}
grammar = tracery.Grammar(rules)
# grammar.flatten("#origin#") # origin is the typical main string name
for i in range(6):
    print(grammar.flatten("#origin#"))
# Out:
# wsup, world!
# wsup, galaxy!
# Howdy, nebula!
# Howdy, world!
# wsup, solar system!
# zoinks, world!

# %%
from tracery.modifiers import base_english

# %%
rules = {
    "origin": "#interj.capitalize# #name#, I'm #profession.a#, not a couple of #profession.s#!",
    "interj": ["zoinks", "whoops", "eureka"],
    "name": ["Jim", "Harold", "Steve"],
    "profession": ["accountant", "venture capitalist", "podiatrist", "zookeeper"]
}

grammar = tracery.Grammar(rules)
grammar.add_modifiers(base_english) # include this to add capitalization
for i in range(6):
    print(grammar.flatten("#origin#"))
    
# [word].capitalize for first letter, [word].a for adding "a" in front, [word].s for adding "s" in front
# Out:
# Whoops Jim, I'm a zookeeper, not a couple of accountants!
# Zoinks Steve, I'm a venture capitalist, not a couple of accountants!
# Zoinks Harold, I'm a zookeeper, not a couple of zookeepers!
# Zoinks Jim, I'm a podiatrist, not a couple of venture capitalists!
# Zoinks Jim, I'm a podiatrist, not a couple of zookeepers!
# Eureka Steve, I'm a podiatrist, not a couple of zookeepers!
