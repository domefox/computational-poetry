# %%
import sys
# !conda install -c conda-forge -y --prefix {sys.prefix} spacy
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Weber\anaconda3
#
#   added / updated specs:
#     - spacy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.2.2   |       h56e8100_0         152 KB  conda-forge
#     catalogue-2.0.10           |  py311h1ea47a8_0          43 KB  conda-forge
#     certifi-2024.2.2           |     pyhd8ed1ab_0         157 KB  conda-forge
#     cloudpathlib-0.16.0        |     pyhd8ed1ab_0          37 KB  conda-forge
#     confection-0.1.4           |  py311h3810d55_0          88 KB  conda-forge
#     cymem-2.0.8                |  py311h12c1d0e_1          42 KB  conda-forge
#     cython-blis-0.7.10         |  py311h59ca53f_2         3.3 MB  conda-forge
#     dataclasses-0.8            |     pyhc8e2a94_3          10 KB  conda-forge
#     langcodes-3.3.0            |     pyhd8ed1ab_0         156 KB  conda-forge
#     murmurhash-1.0.10          |  py311h12c1d0e_1          30 KB  conda-forge
#     openssl-3.2.1              |       hcfcfb64_0         7.8 MB  conda-forge
#     pathy-0.10.2               |     pyhd8ed1ab_0          42 KB  conda-forge
#     preshed-3.0.9              |  py311h12c1d0e_1          90 KB  conda-forge
#     python_abi-3.11            |          2_cp311           5 KB  conda-forge
#     rich-13.7.1                |     pyhd8ed1ab_0         180 KB  conda-forge
#     shellingham-1.5.4          |     pyhd8ed1ab_0          14 KB  conda-forge
#     spacy-3.7.2                |  py311h12feb9d_0         6.2 MB  conda-forge
#     spacy-legacy-3.0.12        |     pyhd8ed1ab_0          28 KB  conda-forge
#     spacy-loggers-1.0.5        |     pyhd8ed1ab_0          21 KB  conda-forge
#     srsly-2.4.8                |  py311h12c1d0e_1         657 KB  conda-forge
#     thinc-8.2.2                |  py311h12feb9d_0         1.0 MB  conda-forge
#     typer-0.9.0                |     pyhd8ed1ab_0          77 KB  conda-forge
#     ucrt-10.0.22621.0          |       h57928b3_0         1.2 MB  conda-forge
#     vc14_runtime-14.38.33130   |      h82b7239_18         732 KB  conda-forge
#     vs2015_runtime-14.38.33130 |      hcb4865c_18          17 KB  conda-forge
#     wasabi-1.1.2               |  py311h1ea47a8_0          57 KB  conda-forge
#     weasel-0.3.4               |     pyhd8ed1ab_0          42 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        22.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   catalogue          conda-forge/win-64::catalogue-2.0.10-py311h1ea47a8_0
#   cloudpathlib       conda-forge/noarch::cloudpathlib-0.16.0-pyhd8ed1ab_0
#   confection         conda-forge/win-64::confection-0.1.4-py311h3810d55_0
#   cymem              conda-forge/win-64::cymem-2.0.8-py311h12c1d0e_1
#   cython-blis        conda-forge/win-64::cython-blis-0.7.10-py311h59ca53f_2
#   dataclasses        conda-forge/noarch::dataclasses-0.8-pyhc8e2a94_3
#   langcodes          conda-forge/noarch::langcodes-3.3.0-pyhd8ed1ab_0
#   murmurhash         conda-forge/win-64::murmurhash-1.0.10-py311h12c1d0e_1
#   pathy              conda-forge/noarch::pathy-0.10.2-pyhd8ed1ab_0
#   preshed            conda-forge/win-64::preshed-3.0.9-py311h12c1d0e_1
#   python_abi         conda-forge/win-64::python_abi-3.11-2_cp311
#   rich               conda-forge/noarch::rich-13.7.1-pyhd8ed1ab_0
#   shellingham        conda-forge/noarch::shellingham-1.5.4-pyhd8ed1ab_0
#   spacy              conda-forge/win-64::spacy-3.7.2-py311h12feb9d_0
#   spacy-legacy       conda-forge/noarch::spacy-legacy-3.0.12-pyhd8ed1ab_0
#   spacy-loggers      conda-forge/noarch::spacy-loggers-1.0.5-pyhd8ed1ab_0
#   srsly              conda-forge/win-64::srsly-2.4.8-py311h12c1d0e_1
#   thinc              conda-forge/win-64::thinc-8.2.2-py311h12feb9d_0
#   typer              conda-forge/noarch::typer-0.9.0-pyhd8ed1ab_0
#   ucrt               conda-forge/win-64::ucrt-10.0.22621.0-h57928b3_0
#   vc14_runtime       conda-forge/win-64::vc14_runtime-14.38.33130-h82b7239_18
#   wasabi             conda-forge/win-64::wasabi-1.1.2-py311h1ea47a8_0
#   weasel             conda-forge/noarch::weasel-0.3.4-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.08.22~ --> conda-forge::ca-certificates-2024.2.2-h56e8100_0
#   certifi            pkgs/main/win-64::certifi-2023.7.22-p~ --> conda-forge/noarch::certifi-2024.2.2-pyhd8ed1ab_0
#   openssl              pkgs/main::openssl-3.0.10-h2bbff1b_2 --> conda-forge::openssl-3.2.1-hcfcfb64_0
#   vs2015_runtime     pkgs/main::vs2015_runtime-14.27.29016~ --> conda-forge::vs2015_runtime-14.38.33130-hcb4865c_18
#
#
#
# Downloading and Extracting Packages
#
# python_abi-3.11      | 5 KB      |            |   0%
#
# spacy-3.7.2          | 6.2 MB    |            |   0%
#
#
# rich-13.7.1          | 180 KB    |            |   0%
#
#
#
# vs2015_runtime-14.38 | 17 KB     |            |   0%
#
#
#
#
# cython-blis-0.7.10   | 3.3 MB    |            |   0%
#
#
#
#
#
# ca-certificates-2024 | 152 KB    |            |   0%
#
#
#
#
#
#
# catalogue-2.0.10     | 43 KB     |            |   0%
#
#
#
#
#
#
#
# typer-0.9.0          | 77 KB     |            |   0%
#
#
#
#
#
#
#
#
# shellingham-1.5.4    | 14 KB     |            |   0%
#
#
#
#
#
#
#
#
#
# spacy-legacy-3.0.12  | 28 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
# preshed-3.0.9        | 90 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# pathy-0.10.2         | 42 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# murmurhash-1.0.10    | 30 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# vc14_runtime-14.38.3 | 732 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.2.1        | 7.8 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wasabi-1.1.2         | 57 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ucrt-10.0.22621.0    | 1.2 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# weasel-0.3.4         | 42 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# srsly-2.4.8          | 657 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# rich-13.7.1          | 180 KB    | 8          |   9%
#
# spacy-3.7.2          | 6.2 MB    |            |   0%
# python_abi-3.11      | 5 KB      | ########## | 100%
#
#
#
# vs2015_runtime-14.38 | 17 KB     | #########6 |  96%
#
#
#
#
#
#
# catalogue-2.0.10     | 43 KB     | ###7       |  37%
#
#
#
#
#
# ca-certificates-2024 | 152 KB    | #          |  11%
#
#
#
#
#
#
#
# typer-0.9.0          | 77 KB     | ##         |  21%
#
# spacy-3.7.2          | 6.2 MB    | #6         |  16%
#
#
#
#
#
#
#
#
# shellingham-1.5.4    | 14 KB     | ########## | 100%
# python_abi-3.11      | 5 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
# spacy-legacy-3.0.12  | 28 KB     | #####7     |  57%
#
#
#
# vs2015_runtime-14.38 | 17 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# preshed-3.0.9        | 90 KB     | #7         |  18%
#
# spacy-3.7.2          | 6.2 MB    | ###1       |  32%
#
#
#
#
#
#
#
#
#
#
#
# pathy-0.10.2         | 42 KB     | ###7       |  38%
#
#
#
#
# cython-blis-0.7.10   | 3.3 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# murmurhash-1.0.10    | 30 KB     | #####2     |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.2.1        | 7.8 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# vc14_runtime-14.38.3 | 732 KB    | 2          |   2%
#
# spacy-3.7.2          | 6.2 MB    | ####6      |  46%
#
#
#
#
# cython-blis-0.7.10   | 3.3 MB    | #3         |  14%
#
#
#
#
#
# ca-certificates-2024 | 152 KB    | ########## | 100%
#
#
#
#
#
# ca-certificates-2024 | 152 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wasabi-1.1.2         | 57 KB     | ##8        |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.2.1        | 7.8 MB    | 4          |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
# vc14_runtime-14.38.3 | 732 KB    | #####      |  50%
#
#
#
#
#
#
# catalogue-2.0.10     | 43 KB     | ########## | 100%
#
#
#
#
#
#
# catalogue-2.0.10     | 43 KB     | ########## | 100%
#
# spacy-3.7.2          | 6.2 MB    | #####8     |  59%
#
#
#
#
# cython-blis-0.7.10   | 3.3 MB    | ##2        |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ucrt-10.0.22621.0    | 1.2 MB    | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.2.1        | 7.8 MB    | 8          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
# vc14_runtime-14.38.3 | 732 KB    | ########9  |  90%
#
#
#
#
# cython-blis-0.7.10   | 3.3 MB    | ###        |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ucrt-10.0.22621.0    | 1.2 MB    | ##9        |  29%
#
# spacy-3.7.2          | 6.2 MB    | #######    |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.2.1        | 7.8 MB    | #1         |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# weasel-0.3.4         | 42 KB     | ###8       |  39%
#
#
#
#
#
#
#
#
# shellingham-1.5.4    | 14 KB     | ########## | 100%
#
#
#
#
# cython-blis-0.7.10   | 3.3 MB    | ###9       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ucrt-10.0.22621.0    | 1.2 MB    | #####3     |  54%
#
# spacy-3.7.2          | 6.2 MB    | ########1  |  81%
#
#
# rich-13.7.1          | 180 KB    | ########## | 100%
#
#
# rich-13.7.1          | 180 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.2.1        | 7.8 MB    | #6         |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# srsly-2.4.8          | 657 KB    | 2          |   2%
#
#
#
#
# cython-blis-0.7.10   | 3.3 MB    | ####8      |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ucrt-10.0.22621.0    | 1.2 MB    | ########   |  80%
#
#
#
#
#
#
#
#
#
# spacy-legacy-3.0.12  | 28 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
# spacy-legacy-3.0.12  | 28 KB     | ########## | 100%
#
# spacy-3.7.2          | 6.2 MB    | #########1 |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.2.1        | 7.8 MB    | ##         |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# srsly-2.4.8          | 657 KB    | ####1      |  41%
#
#
#
#
#
#
#
#
#
#
#
# pathy-0.10.2         | 42 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# pathy-0.10.2         | 42 KB     | ########## | 100%
#
#
#
#
# cython-blis-0.7.10   | 3.3 MB    | #####7     |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.2.1        | 7.8 MB    | ##3        |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# srsly-2.4.8          | 657 KB    | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# cython-blis-0.7.10   | 3.3 MB    | ######7    |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.2.1        | 7.8 MB    | ##8        |  29%
#
#
#
#
#
#
#
#
#
#
# preshed-3.0.9        | 90 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# preshed-3.0.9        | 90 KB     | ########## | 100%
#
#
#
#
# cython-blis-0.7.10   | 3.3 MB    | #######6   |  76%
#
#
#
#
#
#
#
#
#
#
#
#
# murmurhash-1.0.10    | 30 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# murmurhash-1.0.10    | 30 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.2.1        | 7.8 MB    | ###3       |  34%
#
#
#
#
# cython-blis-0.7.10   | 3.3 MB    | ########8  |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.2.1        | 7.8 MB    | ###8       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wasabi-1.1.2         | 57 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wasabi-1.1.2         | 57 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# vc14_runtime-14.38.3 | 732 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.2.1        | 7.8 MB    | ####4      |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.2.1        | 7.8 MB    | #####1     |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# weasel-0.3.4         | 42 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# weasel-0.3.4         | 42 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.2.1        | 7.8 MB    | ######1    |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.2.1        | 7.8 MB    | #######5   |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.2.1        | 7.8 MB    | ########9  |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ucrt-10.0.22621.0    | 1.2 MB    | ########## | 100%
#
#
#
#
#
#
#
# typer-0.9.0          | 77 KB     | ########## | 100%
#
#
#
#
#
#
#
# typer-0.9.0          | 77 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# srsly-2.4.8          | 657 KB    | ########## | 100%
#
#
#
#
# cython-blis-0.7.10   | 3.3 MB    | ########## | 100%
#
#
#
#
# cython-blis-0.7.10   | 3.3 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.2.1        | 7.8 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.2.1        | 7.8 MB    | ########## | 100%
#
# spacy-3.7.2          | 6.2 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 24.1.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.1.2

# %%
import sys
# !{sys.executable} -m spacy download en_core_web_md
# Out:
# Collecting en-core-web-md==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.7.1/en_core_web_md-3.7.1-py3-none-any.whl (42.8 MB)
#      ---------------------------------------- 0.0/42.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/42.8 MB 1.3 MB/s eta 0:00:34
#      ---------------------------------------- 0.4/42.8 MB 6.0 MB/s eta 0:00:08
#       --------------------------------------- 0.9/42.8 MB 8.1 MB/s eta 0:00:06
#      - -------------------------------------- 1.4/42.8 MB 8.8 MB/s eta 0:00:05
#      - -------------------------------------- 1.9/42.8 MB 9.4 MB/s eta 0:00:05
#      -- ------------------------------------- 2.5/42.8 MB 10.0 MB/s eta 0:00:05
#      --- ------------------------------------ 3.2/42.8 MB 10.2 MB/s eta 0:00:04
#      --- ------------------------------------ 3.7/42.8 MB 11.2 MB/s eta 0:00:04
#      ---- ----------------------------------- 4.4/42.8 MB 11.3 MB/s eta 0:00:04
#      ---- ----------------------------------- 5.0/42.8 MB 11.4 MB/s eta 0:00:04
#      ----- ---------------------------------- 5.6/42.8 MB 11.6 MB/s eta 0:00:04
#      ------ --------------------------------- 6.5/42.8 MB 12.1 MB/s eta 0:00:03
#      ------ --------------------------------- 7.0/42.8 MB 12.0 MB/s eta 0:00:03
#      ------- -------------------------------- 7.7/42.8 MB 12.2 MB/s eta 0:00:03
#      ------- -------------------------------- 8.3/42.8 MB 12.6 MB/s eta 0:00:03
#      -------- ------------------------------- 8.9/42.8 MB 12.7 MB/s eta 0:00:03
#      --------- ------------------------------ 9.7/42.8 MB 12.6 MB/s eta 0:00:03
#      --------- ----------------------------- 10.4/42.8 MB 13.4 MB/s eta 0:00:03
#      ---------- ---------------------------- 11.1/42.8 MB 13.6 MB/s eta 0:00:03
#      ---------- ---------------------------- 11.6/42.8 MB 13.9 MB/s eta 0:00:03
#      ----------- --------------------------- 12.3/42.8 MB 14.2 MB/s eta 0:00:03
#      ----------- --------------------------- 13.0/42.8 MB 14.2 MB/s eta 0:00:03
#      ------------ -------------------------- 13.7/42.8 MB 14.6 MB/s eta 0:00:02
#      ------------- ------------------------- 14.3/42.8 MB 14.5 MB/s eta 0:00:02
#      ------------- ------------------------- 15.0/42.8 MB 14.2 MB/s eta 0:00:02
#      -------------- ------------------------ 15.7/42.8 MB 14.6 MB/s eta 0:00:02
#      -------------- ------------------------ 16.0/42.8 MB 14.2 MB/s eta 0:00:02
#      --------------- ----------------------- 16.5/42.8 MB 13.6 MB/s eta 0:00:02
#      --------------- ----------------------- 17.1/42.8 MB 13.6 MB/s eta 0:00:02
#      ---------------- ---------------------- 17.6/42.8 MB 13.4 MB/s eta 0:00:02
#      ---------------- ---------------------- 18.2/42.8 MB 13.6 MB/s eta 0:00:02
#      ----------------- --------------------- 19.0/42.8 MB 13.6 MB/s eta 0:00:02
#      ----------------- --------------------- 19.6/42.8 MB 13.6 MB/s eta 0:00:02
#      ------------------ -------------------- 20.2/42.8 MB 13.6 MB/s eta 0:00:02
#      ------------------ -------------------- 20.8/42.8 MB 13.6 MB/s eta 0:00:02
#      ------------------- ------------------- 21.6/42.8 MB 13.9 MB/s eta 0:00:02
#      -------------------- ------------------ 22.4/42.8 MB 13.6 MB/s eta 0:00:02
#      --------------------- ----------------- 23.1/42.8 MB 13.9 MB/s eta 0:00:02
#      --------------------- ----------------- 23.9/42.8 MB 13.6 MB/s eta 0:00:02
#      ---------------------- ---------------- 24.5/42.8 MB 13.6 MB/s eta 0:00:02
#      ---------------------- ---------------- 25.1/42.8 MB 13.9 MB/s eta 0:00:02
#      ----------------------- --------------- 25.8/42.8 MB 13.4 MB/s eta 0:00:02
#      ----------------------- --------------- 26.3/42.8 MB 13.6 MB/s eta 0:00:02
#      ------------------------ -------------- 26.8/42.8 MB 13.9 MB/s eta 0:00:02
#      ------------------------- ------------- 27.6/42.8 MB 14.6 MB/s eta 0:00:02
#      ------------------------- ------------- 28.2/42.8 MB 14.2 MB/s eta 0:00:02
#      -------------------------- ------------ 29.0/42.8 MB 14.2 MB/s eta 0:00:01
#      --------------------------- ----------- 29.8/42.8 MB 14.2 MB/s eta 0:00:01
#      --------------------------- ----------- 30.4/42.8 MB 14.6 MB/s eta 0:00:01
#      ---------------------------- ---------- 31.1/42.8 MB 14.6 MB/s eta 0:00:01
#      ----------------------------- --------- 31.8/42.8 MB 14.2 MB/s eta 0:00:01
#      ----------------------------- --------- 32.5/42.8 MB 14.2 MB/s eta 0:00:01
#      ------------------------------ -------- 33.2/42.8 MB 13.9 MB/s eta 0:00:01
#      ------------------------------ -------- 33.9/42.8 MB 14.2 MB/s eta 0:00:01
#      ------------------------------- ------- 34.4/42.8 MB 14.2 MB/s eta 0:00:01
#      -------------------------------- ------ 35.2/42.8 MB 14.2 MB/s eta 0:00:01
#      -------------------------------- ------ 35.9/42.8 MB 14.2 MB/s eta 0:00:01
#      --------------------------------- ----- 36.7/42.8 MB 14.9 MB/s eta 0:00:01
#      ---------------------------------- ---- 37.4/42.8 MB 14.6 MB/s eta 0:00:01
#      ---------------------------------- ---- 38.2/42.8 MB 14.6 MB/s eta 0:00:01
#      ----------------------------------- --- 38.9/42.8 MB 14.9 MB/s eta 0:00:01
#      ------------------------------------ -- 39.6/42.8 MB 14.9 MB/s eta 0:00:01
#      ------------------------------------ -- 40.3/42.8 MB 14.9 MB/s eta 0:00:01
#      ------------------------------------- - 40.9/42.8 MB 14.6 MB/s eta 0:00:01
#      ------------------------------------- - 41.5/42.8 MB 14.9 MB/s eta 0:00:01
#      --------------------------------------  42.2/42.8 MB 14.9 MB/s eta 0:00:01
#      --------------------------------------  42.8/42.8 MB 14.6 MB/s eta 0:00:01
#      --------------------------------------  42.8/42.8 MB 14.6 MB/s eta 0:00:01
#      --------------------------------------- 42.8/42.8 MB 13.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\weber\anaconda3\lib\site-packages (from en-core-web-md==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\weber\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\weber\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\weber\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\weber\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\weber\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\weber\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\weber\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\weber\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\weber\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\weber\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\weber\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\weber\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\weber\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\weber\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\weber\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\weber\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\weber\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\weber\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\weber\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\weber\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\weber\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\weber\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\weber\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\weber\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\weber\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\weber\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\weber\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\users\weber\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\weber\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\weber\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\weber\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.1.1)
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.7.1
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
import spacy

# %%
nlp=spacy.load('en_core_web_md')

# %%
doc = nlp(open("./frankenstein.txt", encoding='utf8').read()) #./ + [tab] lets you see everything in your file

# %%
sentences = list(doc.sents) 
words = [item for item in list(doc) if item.is_alpha]
noun_chunks = list(doc.noun_chunks) # nouns
entities = list(doc.ents) # proper nouns

# %%
import random

# %%
random.sample(words, 10)
# Out:
# [her, some, woman, in, in, own, it, whose, league, I]

# %%
random.sample(noun_chunks, 10)
# Out:
# [I,
#  more necessary beings,
#  mountains,
#  my arms,
#  repose and
#  peace,
#  the scene,
#  I,
#  our actions,
#  sadness,
#  my
#  miseries]

# %%
random.sample(entities, 10)
# Out:
# [MY DEAREST,
#  Elizabeth,
#  Europe,
#  Amadis,
#  nearly two days’,
#  one,
#  one,
#  second,
#  Ernest,
#  Beaufort]

# %%
type(words[100])
# Out:
# spacy.tokens.token.Token

# %%
for i in range(10):
    word = random.choice(entities)
    print(word.text, word.label) # label is the type
# Out:
# Ernest 380
# an
# hour 392
# one 397
# M. Waldman 380
# M. Krempe 380
# Agatha 380
# Two years 391
# morrow 391
# Frankenstein 380
# 17—. 397

# %%
words[1000].text, words[1000].tag_
# Out:
# ('the', 'DT')

# %%
nouns = [item for item in words if item.pos_=='NOUN']
ings = [item for item in words if item.tag_=='VBG']

# %%
random.sample(nouns, 10)
# Out:
# [fiction,
#  purpose,
#  point,
#  joy,
#  moment,
#  feelings,
#  stream,
#  lassitude,
#  nature,
#  soul]
